# %%
import os
from dotenv import load_dotenv

load_dotenv()

# Check if variables are loaded
groq_key = os.getenv('GROQ_API_KEY')
langchain_key = os.getenv('LANGCHAIN_API_KEY')

if not groq_key or not langchain_key:
    raise ValueError("Missing required environment variables in .env file")

os.environ['GROQ_API_KEY'] = groq_key
os.environ['LANGCHAIN_API_KEY'] = langchain_key
os.environ['LANGCHAIN_TRACING_V2'] = 'true' 
os.environ['LANGCHAIN_PROJECT'] = langchain_key

# %%
from langchain_groq import ChatGroq
LLM=ChatGroq(model='llama-3.1-8b-instant',temperature=0.7)

# %%
result=LLM.invoke("Who is president of india?")

# %%
result.content
# Out:
# 'The current President of India is Droupadi Murmu. She took office on July 25, 2022, succeeding Ram Nath Kovind.'

# %%
##Prompt Template
from langchain_core.prompts import ChatPromptTemplate
prompt=ChatPromptTemplate.from_messages([
    ("system","you are a helpful assistant,and provide accurate answer to question?"),
    ("user","{input}")
])
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='you are a helpful assistant,and provide accurate answer to question?'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain= prompt | LLM
response=chain.invoke({"input":"Can you tell me what is Langchain?"})
print(response.content)
# Out:
# LangChain is a relatively new and rapidly evolving technology that has been gaining attention in the AI space. It is an open-source framework for building large language models, particularly those based on the transformer architecture.
#
# LangChain is designed to make it easier for developers to create, train, and deploy large language models, often referred to as LLMs or LLMs. These models are trained on massive datasets and can perform a wide range of natural language processing (NLP) tasks, such as:
#
# 1. Text generation
# 2. Text classification
# 3. Sentiment analysis
# 4. Machine translation
# 5. Summarization
#
# The main goal of LangChain is to provide a unified platform for building and deploying LLMs, making it easier for developers to create innovative applications and integrations. LangChain aims to simplify the process of building and integrating LLMs into various applications, such as chatbots, virtual assistants, and other conversational AI systems.
#
# ...

# %%
#Output Parse - No content we get output here directly
from langchain_core.output_parsers import StrOutputParser
parser=StrOutputParser()
chain=prompt | LLM | parser
response=chain.invoke({"input":"Explain the theory of relativity in simple terms."})

# %%
response
# Out:
# "The theory of relativity, developed by Albert Einstein, is a complex concept that can be difficult to understand. However, I'll try to break it down in simple terms.\n\n**What is the Theory of Relativity?**\n\nThe theory of relativity is a way to understand how space and time are connected. It's divided into two main parts: Special Relativity and General Relativity.\n\n**Special Relativity**\n\nSpecial Relativity says that how we see time and space can be different depending on how fast we're moving and where we are. Here are some key points:\n\n1. **Time is relative**: Time can seem to pass differently for two people moving at different speeds. Imagine two friends, one on a train and the other on the platform. If the train is moving really fast, time might seem to pass more slowly for the person on the train compared to the person on the platform.\n2. **The speed of light is always the same**: No matter how fast you're moving, the speed of light always remains the same. This is a f
# ...
