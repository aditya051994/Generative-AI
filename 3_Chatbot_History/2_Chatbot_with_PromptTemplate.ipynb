# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Check if variables are loaded 
groq_key = os.getenv('GROQ_API_KEY')
if not groq_key :
    raise ValueError("Missing required environment variables in .env file")
os.environ['GROQ_API_KEY'] = groq_key

# %%
from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder

# %%
from langchain_groq import ChatGroq
LLM=ChatGroq(model='llama-3.1-8b-instant',temperature=0.7)

# %%
prompt=ChatPromptTemplate.from_messages([
    ("system","You are a helpful assistant.Answer all the questions to the best of your ability."),
    MessagesPlaceholder(variable_name="message")])
chain=LLM | prompt

# %%
from langchain_core.messages import HumanMessage, SystemMessage,AIMessage
res=chain.invoke({"message":HumanMessage(content="Who is the president of the United States?")})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 from langchain_core.messages import HumanMessage, SystemMessage,AIMessage
# ----> 2 res=chain.invoke({"message":HumanMessage(content="Who is the president of the United States?")})
#
# File c:\Gen-Agent-AI\lib\site-packages\langchain_core\runnables\base.py:3149, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3147 with set_config_context(config) as context:
#    3148     if i == 0:
# -> 3149         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3150     else:
#    3151         input_ = context.run(step.invoke, input_, config)
#
# File c:\Gen-Agent-AI\lib\site-packages\langchain_core\language_models\chat_models.py:399, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)
#     391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
#     398             self.generate_prompt(
# --> 399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File c:\Gen-Agent-AI\lib\site-packages\langchain_core\language_models\chat_models.py:382, in BaseChatModel._convert_input(self, model_input)
#     377     return ChatPromptValue(messages=convert_to_messages(model_input))
#     378 msg = (
#     379     f"Invalid input type {type(model_input)}. "
#     380     "Must be a PromptValue, str, or list of BaseMessages."
#     381 )
# --> 382 raise ValueError(msg)
#
# ValueError: Invalid input type <class 'dict'>. Must be a PromptValue, str, or list of BaseMessages.
