# %%
pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in c:\gen-agent-ai\lib\site-packages (0.36.0)
# Requirement already satisfied: filelock in c:\gen-agent-ai\lib\site-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\gen-agent-ai\lib\site-packages (from huggingface_hub) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\gen-agent-ai\lib\site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: packaging>=20.9 in c:\gen-agent-ai\lib\site-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: requests in c:\gen-agent-ai\lib\site-packages (from huggingface_hub) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\gen-agent-ai\lib\site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\gen-agent-ai\lib\site-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: colorama in c:\gen-agent-ai\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\gen-agent-ai\lib\site-packages (from requests->huggingface_hub) (2025.11.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\gen-agent-ai\lib\site-packages (from requests->huggingface_hub) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\gen-agent-ai\lib\site-packages (from requests->huggingface_hub) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\gen-agent-ai\lib\site-packages (from requests->huggingface_hub) (2.3.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Gen-Agent-AI\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_huggingface import HuggingFaceEndpoint
repo_id="llama-3.1-8b-instant"
LLM=HuggingFaceEndpoint(repo_id=repo_id,huggingfacehub_api_token=os.getenv('HF_TOKEN'))

# %%
LLM.invoke("What is Machine learning")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Gen-Agent-AI\lib\site-packages\huggingface_hub\utils\_http.py:402, in hf_raise_for_status(response, endpoint_name)
#     401 try:
# --> 402     response.raise_for_status()
#     403 except HTTPError as e:
#
# File c:\Gen-Agent-AI\lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/api/models/llama-3.1-8b-instant?expand=inferenceProviderMapping
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 LLM.invoke("What is Machine learning")
#
# File c:\Gen-Agent-AI\lib\site-packages\langchain_core\language_models\llms.py:375, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     364 @override
#     365 def invoke(
#     366     self,
#    (...)
#     371     **kwargs: Any,
#     372 ) -> str:
#     373     config = ensure_config(config)
#     374     return (
# --> 375         self.generate_prompt(
#     376             [self._convert_input(input)],
#     377             stop=stop,
#     378             callbacks=config.get("callbacks"),
#     379             tags=config.get("tags"),
#     380             metadata=config.get("metadata"),
#     381             run_name=config.get("run_name"),
#     382             run_id=config.pop("run_id", None),
#     383             **kwargs,
#     384         )
#     385         .generations[0][0]
#     386         .text
#     387     )
#
# File c:\Gen-Agent-AI\lib\site-packages\langchain_core\language_models\llms.py:786, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     777 @override
#     778 def generate_prompt(
#     779     self,
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_strings = [p.to_string() for p in prompts]
# --> 786     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Gen-Agent-AI\lib\site-packages\langchain_core\language_models\llms.py:1008, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     989 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     990     run_managers = [
#     991         callback_manager.on_llm_start(
#     992             self._serialized,
#    (...)
#    1006         )
#    1007     ]
# -> 1008     return self._generate_helper(
#    1009         prompts,
#    1010         stop,
#    1011         run_managers,
#    1012         new_arg_supported=bool(new_arg_supported),
#    1013         **kwargs,
#    1014     )
#    1015 if len(missing_prompts) > 0:
#    1016     run_managers = [
#    1017         callback_managers[idx].on_llm_start(
#    1018             self._serialized,
#    (...)
#    1025         for idx in missing_prompt_idxs
#    1026     ]
#
# File c:\Gen-Agent-AI\lib\site-packages\langchain_core\language_models\llms.py:812, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     801 def _generate_helper(
#     802     self,
#     803     prompts: list[str],
#    (...)
#     808     **kwargs: Any,
#     809 ) -> LLMResult:
#     810     try:
#     811         output = (
# --> 812             self._generate(
#     813                 prompts,
#     814                 stop=stop,
#     815                 # TODO: support multiple run managers
#     816                 run_manager=run_managers[0] if run_managers else None,
#     817                 **kwargs,
#     818             )
#     819             if new_arg_supported
#     820             else self._generate(prompts, stop=stop)
#     821         )
#     822     except BaseException as e:
#     823         for run_manager in run_managers:
#
# File c:\Gen-Agent-AI\lib\site-packages\langchain_core\language_models\llms.py:1502, in LLM._generate(self, prompts, stop, run_manager, **kwargs)
#    1499 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#    1500 for prompt in prompts:
#    1501     text = (
# -> 1502         self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1503         if new_arg_supported
#    1504         else self._call(prompt, stop=stop, **kwargs)
#    1505     )
#    1506     generations.append([Generation(text=text)])
#    1507 return LLMResult(generations=generations)
#
# File c:\Gen-Agent-AI\lib\site-packages\langchain_huggingface\llms\huggingface_endpoint.py:341, in HuggingFaceEndpoint._call(self, prompt, stop, run_manager, **kwargs)
#     338         completion += chunk.text
#     339     return completion
# --> 341 response_text = self.client.text_generation(
#     342     prompt=prompt,
#     343     model=self.model,
#     344     **invocation_params,
#     345 )
#     347 # Maybe the generation has stopped at one of the stop sequences:
#     348 # then we remove this stop sequence from the end of the generated text
#     349 for stop_seq in invocation_params["stop"]:
#
# File c:\Gen-Agent-AI\lib\site-packages\huggingface_hub\inference\_client.py:2356, in InferenceClient.text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2350         raise ValueError(
#    2351             "API endpoint/model for text-generation is not served via TGI. Cannot return output as a stream."
#    2352             " Please pass `stream=False` as input."
#    2353         )
#    2355 model_id = model or self.model
# -> 2356 provider_helper = get_provider_helper(self.provider, task="text-generation", model=model_id)
#    2357 request_parameters = provider_helper.prepare_request(
#    2358     inputs=prompt,
#    2359     parameters=parameters,
#    (...)
#    2363     api_key=self.token,
#    2364 )
#    2366 # Handle errors separately for more precise error messages
#
# File c:\Gen-Agent-AI\lib\site-packages\huggingface_hub\inference\_providers\__init__.py:216, in get_provider_helper(provider, task, model)
#     214     if model is None:
#     215         raise ValueError("Specifying a model is required when provider is 'auto'")
# --> 216     provider_mapping = _fetch_inference_provider_mapping(model)
#     217     provider = next(iter(provider_mapping)).provider
#     219 provider_tasks = PROVIDERS.get(provider)  # type: ignore
#
# File c:\Gen-Agent-AI\lib\site-packages\huggingface_hub\inference\_providers\_common.py:307, in _fetch_inference_provider_mapping(model)
#     302 """
#     303 Fetch provider mappings for a model from the Hub.
#     304 """
#     305 from huggingface_hub.hf_api import HfApi
# --> 307 info = HfApi().model_info(model, expand=["inferenceProviderMapping"])
#     308 provider_mapping = info.inference_provider_mapping
#     309 if provider_mapping is None:
#
# File c:\Gen-Agent-AI\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Gen-Agent-AI\lib\site-packages\huggingface_hub\hf_api.py:2661, in HfApi.model_info(self, repo_id, revision, timeout, securityStatus, files_metadata, expand, token)
#    2659     params["expand"] = expand
#    2660 r = get_session().get(path, headers=headers, timeout=timeout, params=params)
# -> 2661 hf_raise_for_status(r)
#    2662 data = r.json()
#    2663 return ModelInfo(**data)
#
# File c:\Gen-Agent-AI\lib\site-packages\huggingface_hub\utils\_http.py:452, in hf_raise_for_status(response, endpoint_name)
#     431 elif error_code == "RepoNotFound" or (
#     432     response.status_code == 401
#     433     and error_message != "Invalid credentials in Authorization header"
#    (...)
#     441     # => for now, we process them as `RepoNotFound` anyway.
#     442     # See https://gist.github.com/Wauplin/46c27ad266b15998ce56a6603796f0b9
#     443     message = (
#     444         f"{response.status_code} Client Error."
#     445         + "\n\n"
#    (...)
#     450         " https://huggingface.co/docs/huggingface_hub/authentication"
#     451     )
# --> 452     raise _format(RepositoryNotFoundError, message, response) from e
#     454 elif response.status_code == 400:
#     455     message = (
#     456         f"\n\nBad request for {endpoint_name} endpoint:" if endpoint_name is not None else "\n\nBad request:"
#     457     )
#
# RepositoryNotFoundError: 404 Client Error. (Request ID: Root=1-69730557-5ea8782977a0cbd5319bbf50;68d928ff-704b-442a-86d4-2cb2d401f9dc)
#
# Repository Not Found for url: https://huggingface.co/api/models/llama-3.1-8b-instant?expand=inferenceProviderMapping.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication

# %%
We
